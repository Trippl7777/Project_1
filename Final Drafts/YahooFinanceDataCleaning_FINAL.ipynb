# %%
# %matplotlib inline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
#BCH data make new df with only close and date columns and rename close column to BCH
bch_raw = 'Cryptos - YF/BCH-USD.csv'
bch_df = pd.read_csv(bch_raw, low_memory=False)
bch = bch_df[["Date", "Close"]]
c = bch["Close"].count()
clean_bch= bch.rename(columns={"Close": "BCH_Close"})
clean_bch["BCH_PC"] = clean_bch["BCH_Close"].pct_change()

#BNB follow same process as above
bnb_raw = 'Cryptos - YF/BNB-USD.csv'
bnb_df = pd.read_csv(bnb_raw, low_memory=False)
bnb = bnb_df[["Date", "Close"]]
c += bnb["Close"].count()
clean_bnb= bnb.rename(columns={"Close": "BNB_Close"})
clean_bnb["BNB_PC"] = clean_bnb["BNB_Close"].pct_change()


#BTC follow same process as above
btc_raw = 'Cryptos - YF/BTC-USD.csv'
btc_df = pd.read_csv(btc_raw, low_memory=False)
btc = btc_df[["Date", "Close"]]
c += btc["Close"].count()
clean_btc= btc.rename(columns={"Close": "BTC_Close"})
clean_btc["BTC_PC"] = clean_btc["BTC_Close"].pct_change()

#EOS follow same process as above
eos_raw = 'Cryptos - YF/EOS-USD.csv'
eos_df = pd.read_csv(eos_raw, low_memory=False)
eos = eos_df[["Date", "Close"]]
c += eos["Close"].count()
clean_eos= eos.rename(columns={"Close": "EOS_Close"})
clean_eos["EOS_PC"] = clean_eos["EOS_Close"].pct_change()


#ETH follow same process as above
eth_raw = 'Cryptos - YF/ETH-USD.csv'
eth_df = pd.read_csv(eth_raw, low_memory=False)
eth = eth_df[["Date", "Close"]]
c += eth["Close"].count()
clean_eth= eth.rename(columns={"Close": "ETH_Close"})
clean_eth["ETH_PC"] = clean_eth["ETH_Close"].pct_change()

#LINK follow same process as above
link_raw = 'Cryptos - YF/LINK-USD.csv'
link_df = pd.read_csv(link_raw, low_memory=False)
link = link_df[["Date", "Close"]]
c += link["Close"].count()
clean_link= link.rename(columns={"Close": "LINK_Close"})
clean_link["LINK_PC"] = clean_link["LINK_Close"].pct_change()

#LTC follow same process as above
ltc_raw = 'Cryptos - YF/LTC-USD.csv'
ltc_df = pd.read_csv(ltc_raw, low_memory=False)
ltc = ltc_df[["Date", "Close"]]
c += ltc["Close"].count()
clean_ltc= ltc.rename(columns={"Close": "LTC_Close"})
clean_ltc["LTC_PC"] = clean_ltc["LTC_Close"].pct_change()

#TRX follow same process as above
trx_raw = 'Cryptos - YF/TRX-USD.csv'
trx_df = pd.read_csv(trx_raw, low_memory=False)
trx = trx_df[["Date", "Close"]]
c += trx["Close"].count()
clean_trx= trx.rename(columns={"Close": "TRX_Close"})
clean_trx["TRX_PC"] = clean_trx["TRX_Close"].pct_change()

#XLM follow same process as above
xlm_raw = 'Cryptos - YF/XLM-USD.csv'
xlm_df = pd.read_csv(xlm_raw, low_memory=False)
xlm = xlm_df[["Date", "Close"]]
c += xlm["Close"].count()
clean_xlm= xlm.rename(columns={"Close": "XLM_Close"})
clean_xlm["XLM_PC"] = clean_xlm["XLM_Close"].pct_change()

#XRP follow same process as above
xrp_raw = 'Cryptos - YF/XRP-USD.csv'
xrp_df = pd.read_csv(xrp_raw, low_memory=False)
xrp = xrp_df[["Date", "Close"]]
c += xrp["Close"].count()
clean_xrp= xrp.rename(columns={"Close": "XRP_Close"})
clean_xrp["XRP_PC"] = clean_xrp["XRP_Close"].pct_change()

#merge all clean df's into one big df
BCH_BNB= pd.merge(clean_bch, clean_bnb, how ="inner", on= "Date")
BTC_EOS= pd.merge(clean_btc, clean_eos, how ="inner", on= "Date")
ETH_LINK= pd.merge(clean_eth, clean_link, how ="inner", on= "Date")
LTC_TRX= pd.merge(clean_ltc, clean_trx, how ="inner", on= "Date")
XLM_XRP= pd.merge(clean_xlm, clean_xrp, how ="inner", on= "Date")

BCH_EOS= pd.merge(BCH_BNB, BTC_EOS, how ="inner", on= "Date")
ETH_TRX=pd.merge(ETH_LINK, LTC_TRX, how ="inner", on= "Date")
BCH_TRX=pd.merge(BCH_EOS, ETH_TRX, how="inner", on= "Date")

Yahoo_Combined= pd.merge(BCH_TRX, XLM_XRP, how="inner", on="Date")

Yahoo_Combined
# Out:
#            Date   BCH_Close    BCH_PC  BNB_Close    BNB_PC     BTC_Close  \
# 0    2017-09-21  416.130005 -0.128067   0.701800 -0.096084   3617.270020
# 1    2017-09-22  409.630005 -0.015620   0.715800  0.019949   3600.830078
# 2    2017-09-23  430.309998  0.050485   0.771600  0.077955   3788.020020
# 3    2017-09-24  421.190002 -0.021194   0.784800  0.017107   3667.520020
# 4    2017-09-25  450.850006  0.070420   0.926200  0.180173   3932.830078
# 5    2017-09-26  449.559998 -0.002861   0.864200 -0.066940   3892.699951
# 6    2017-09-27  464.140015  0.032432   1.153000  0.334182   4212.200195
# 7    2017-09-28  458.149994 -0.012906   1.375000  0.192541   4195.649902
# 8    2017-09-29  440.549988 -0.038415   1.273000 -0.074182   4172.790039
# 9    2017-09-30  435.950012 -0.010441   1.289000  0.012569   4360.620117
# 10   2017-10-01  418.049988 -0.041060   1.523000  0.181536   4403.089844
# 11   2017-10-02  419.679993  0.003899   1.970000  0.293500   4401.319824
# ...

# %%
Yahoo_Combined = Yahoo_Combined.drop([0], axis=0)
Yahoo_Combined
# Out:
#            Date   BCH_Close    BCH_PC  BNB_Close    BNB_PC     BTC_Close  \
# 1    2017-09-22  409.630005 -0.015620   0.715800  0.019949   3600.830078
# 2    2017-09-23  430.309998  0.050485   0.771600  0.077955   3788.020020
# 3    2017-09-24  421.190002 -0.021194   0.784800  0.017107   3667.520020
# 4    2017-09-25  450.850006  0.070420   0.926200  0.180173   3932.830078
# 5    2017-09-26  449.559998 -0.002861   0.864200 -0.066940   3892.699951
# 6    2017-09-27  464.140015  0.032432   1.153000  0.334182   4212.200195
# 7    2017-09-28  458.149994 -0.012906   1.375000  0.192541   4195.649902
# 8    2017-09-29  440.549988 -0.038415   1.273000 -0.074182   4172.790039
# 9    2017-09-30  435.950012 -0.010441   1.289000  0.012569   4360.620117
# 10   2017-10-01  418.049988 -0.041060   1.523000  0.181536   4403.089844
# 11   2017-10-02  419.679993  0.003899   1.970000  0.293500   4401.319824
# 12   2017-10-03  401.410004 -0.043533   1.842000 -0.064975   4314.180176
# ...

# %%
Yahoo_Combined.replace([np.inf,-np.inf], np.nan,inplace=True)
Yahoo_Combined=Yahoo_Combined.fillna(0)

Yahoo_Combined
# Out:
#            Date   BCH_Close    BCH_PC  BNB_Close    BNB_PC     BTC_Close  \
# 1    2017-09-22  409.630005 -0.015620   0.715800  0.019949   3600.830078
# 2    2017-09-23  430.309998  0.050485   0.771600  0.077955   3788.020020
# 3    2017-09-24  421.190002 -0.021194   0.784800  0.017107   3667.520020
# 4    2017-09-25  450.850006  0.070420   0.926200  0.180173   3932.830078
# 5    2017-09-26  449.559998 -0.002861   0.864200 -0.066940   3892.699951
# 6    2017-09-27  464.140015  0.032432   1.153000  0.334182   4212.200195
# 7    2017-09-28  458.149994 -0.012906   1.375000  0.192541   4195.649902
# 8    2017-09-29  440.549988 -0.038415   1.273000 -0.074182   4172.790039
# 9    2017-09-30  435.950012 -0.010441   1.289000  0.012569   4360.620117
# 10   2017-10-01  418.049988 -0.041060   1.523000  0.181536   4403.089844
# 11   2017-10-02  419.679993  0.003899   1.970000  0.293500   4401.319824
# 12   2017-10-03  401.410004 -0.043533   1.842000 -0.064975   4314.180176
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats

# %% [markdown]
# Group Assignments
# -----
# - group1= BTC
# - group2= BNB
# - group3= BCH
# - group4= EOS
# - group5 =ETH
# - group6= LINK
# - group7= LTC
# - group8= TRX
# - group9= XLM
# - group10= XRP

# %%
group1 = Yahoo_Combined["BTC_PC"]
group2 = Yahoo_Combined["BNB_PC"]
group3 = Yahoo_Combined["BCH_PC"]
group4 = Yahoo_Combined["EOS_PC"]
group5 = Yahoo_Combined["ETH_PC"]
group6 = Yahoo_Combined["LINK_PC"]
group7 = Yahoo_Combined["LTC_PC"]
group8 = Yahoo_Combined["TRX_PC"]
group9 = Yahoo_Combined["XLM_PC"]
group10 = Yahoo_Combined["XRP_PC"]

gp_ls = [group2, group3, group4, group5, group6, group7, group8, group9, group10 ]

# %%
for x in gp_ls:
    anova = stats.f_oneway(group1, x)
    print(anova)
# Out:
# F_onewayResult(statistic=2.803984215364113, pvalue=0.09426442901319942)
# F_onewayResult(statistic=0.0003329928598264897, pvalue=0.985443661912328)
# F_onewayResult(statistic=1.0635552658438565, pvalue=0.30259236429517394)
# F_onewayResult(statistic=0.21960049594011763, pvalue=0.6394209383910445)
# F_onewayResult(statistic=0.7359168160752195, pvalue=0.39112588111457236)
# F_onewayResult(statistic=0.02703425705940751, pvalue=0.8694246241274969)
# F_onewayResult(statistic=2.1601100020060393, pvalue=0.1418699915970896)
# F_onewayResult(statistic=1.0905578507239793, pvalue=0.2965365546260949)
# F_onewayResult(statistic=0.08331722224687234, pvalue=0.7728961279347355)

# %% [markdown]
# #ttest of BTC against all other groups
# - BTCBNB_ttest= stats.ttest_ind(group1, group2, equal_var=False)
# - BTCBCH_ttest=stats.ttest_ind(group1, group3, equal_var=False)
# - BTCEOS_ttest=stats.ttest_ind(group1, group4, equal_var=False)
# - BTCETH_ttest=stats.ttest_ind(group1, group5, equal_var=False)
# - BTCLINK_ttest=stats.ttest_ind(group1, group6, equal_var=False)
# - BTCLTC_ttest=stats.ttest_ind(group1, group7, equal_var=False)
# - BTCTRX_ttest=stats.ttest_ind(group1, group8, equal_var=False)
# - BTCXLM_ttest=stats.ttest_ind(group1, group9, equal_var=False)
# - BTCXRP_ttest=stats.ttest_ind(group1, group10, equal_var=False)

# %% [markdown]
# Color Assignments for plotting
# ------
# - Bitcoin, BTC, gold
# - Binance Coin, BNB, light green
# - Bitcoin Cash, BCH, tan
# - EOS, EOS, light coral
# - ETH, Ethereum, light grey
# - LINK, Chainlink, medium purple
# - LTC, Litecoin, magenta
# - TRX,Tron, light red
# - XLM, Stellar, cyan
# - XRP,Ripple, light blue

# %%
#histogram BTC and BNB
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group2, 10, density=True, alpha=0.7, label="BNB", color='lightgreen', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group2.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Binance Coin Distribution", fontsize=14)
BTCBNB_ttest= stats.ttest_ind(group1, group2, equal_var=False)
plt.text(-.3, -1.5, BTCBNB_ttest, fontsize=11)
plt.savefig('Images/BTCBNBhist.png')

# %%
#scatterplot BTC BNB
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group2)), group2, s=100, label="BNB", alpha=0.5, c='lightgreen', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Binance Coin Distribution", fontsize=14)
plt.text(0, -.5, BTCBNB_ttest, fontsize=11)
plt.savefig('Images/BTCBNBscat.png')

# %%
#histogram BTC and BCH
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group3, 10, density=True, alpha=0.7, label="BCH", color='tan', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group3.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Bitcoin Cash Distribution", fontsize=14)
BTCBCH_ttest= stats.ttest_ind(group1, group3, equal_var=False)

plt.text(-.3, -1.5, BTCBCH_ttest, fontsize=11)
plt.savefig('Images/BTCBCHhist.png')

# %%
#scatterplot BTC BCH
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group3)), group3, s=100, label="BCH", alpha=0.5, c='tan', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Bitcoin Cash Distribution", fontsize=14)
plt.text(0, -.4, BTCBCH_ttest, fontsize=11)
plt.savefig('Images/BTCBCHscat.png')

# %%
#histogram BTC and EOS
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group4, 10, density=True, alpha=0.5, label="EOS", color='lightcoral', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group4.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and EOS Distribution", fontsize=14)
BTCEOS_ttest= stats.ttest_ind(group1, group4, equal_var=False)

plt.text(-.3, -1.5, BTCEOS_ttest, fontsize=11)
plt.savefig('Images/BTCEOShis.png')

# %%
#scatterplot BTC EOS
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group4)), group4, s=100, label="EOS", alpha=0.5, c='lightcoral', edgecolor='black')
plt.legend()
plt.title("Bitcoin and EOS Distribution", fontsize=14)
plt.text(0, -.4, BTCEOS_ttest, fontsize=11)
plt.savefig('Images/BTCEOSscat.png')

# %%
#histogram BTC and ETH
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group5, 10, density=True, alpha=0.7, label="ETH", color='lightgrey', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group5.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Ethereum Distribution", fontsize=14)
BTCETH_ttest= stats.ttest_ind(group1, group5, equal_var=False)

plt.text(-.2, -1.5, BTCETH_ttest, fontsize=11)
plt.savefig('Images/BTCETHhis.png')

# %%
#scatterplot BTC ETH
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group5)), group5, s=100, label="ETH", alpha=0.5, c='lightgrey', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Ethereum Distribution", fontsize=14)
plt.text(0, -.3, BTCETH_ttest, fontsize=11)
plt.savefig('Images/BTCETHscat.png')

# %%
#histogram BTC and LINK
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group6, 10, density=True, alpha=0.5, label="LINK", color='mediumpurple', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group6.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Chainlink Distribution", fontsize=14)
BTCLINK_ttest= stats.ttest_ind(group1, group6, equal_var=False)

plt.text(-1, -1.5, BTCLINK_ttest, fontsize=11)
plt.savefig('Images/BTCLINKhis.png')

# %%
#scatterplot BTC LINK
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group6)), group6, s=100, label="LINK", alpha=0.5, c='mediumpurple', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Chainlink Distribution", fontsize=14)
plt.text(0, -1.3, BTCLINK_ttest, fontsize=11)
plt.savefig('Images/BTCLINKscat.png')

# %%
#histogram BTC and LTC
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group7, 10, density=True, alpha=0.5, label="LTC", color='magenta', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group7.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Litecoin Distribution", fontsize=14)
BTCLTC_ttest= stats.ttest_ind(group1, group7, equal_var=False)

plt.text(-.2, -1.5, BTCLTC_ttest, fontsize=11)
plt.savefig('Images/BTCLTChis.png')

# %%
#scatterplot BTC LTC
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group7)), group7, s=100, label="LTC", alpha=0.5, c='magenta', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Litecoin Distribution", fontsize=14)
plt.text(0, -.35, BTCLTC_ttest, fontsize=11)
plt.savefig('Images/BTCLTCscat.png')

# %%
#histogram BTC and TRX
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group8, 10, density=True, alpha=0.4, label="TRX", color='r', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group8.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Tron Distribution", fontsize=14)
BTCTRX_ttest= stats.ttest_ind(group1, group8, equal_var=False)

plt.text(-.4, -1.5, BTCTRX_ttest, fontsize=11)
plt.savefig('Images/BTCTRXhis.png')

# %%
#scatterplot BTC TRX
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group8)), group8, s=100, label="TRX", alpha=0.4, c='r', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Tron Distribution", fontsize=14)
plt.text(0, -.6, BTCTRX_ttest, fontsize=11)
plt.savefig('Images/BTCTRXscat.png')

# %%
#histogram BTC and XLM
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group9, 10, density=True, alpha=0.4, label="XLM", color='cyan', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group9.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Stellar Distribution", fontsize=14)
BTCXLM_ttest= stats.ttest_ind(group1, group9, equal_var=False)

plt.text(-.3, -1.5, BTCXLM_ttest, fontsize=11)
plt.savefig('Images/BTCXLMhis.png')

# %%
#scatterplot BTC XLM
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group9)), group9, s=100, label="XLM", alpha=0.4, c='cyan', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Stellar Distribution", fontsize=14)
plt.text(0, -.5, BTCXLM_ttest, fontsize=11)
plt.savefig('Images/BTCXLMscat.png')

# %%
#histogram BTC and XRP
plt.figure(figsize=(9,7))
plt.hist(group1, 10, density=True, alpha=0.7, label="BTC", color='gold', edgecolor='grey')
plt.hist(group10, 10, density=True, alpha=0.5, label="XRP", color='royalblue', edgecolor='grey')
plt.axvline(group1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(group10.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title("Bitcoin and Ripple Distribution", fontsize=14)
BTCXRP_ttest= stats.ttest_ind(group1, group10, equal_var=False)

plt.text(-.3, -1.5, BTCXRP_ttest, fontsize=11)
plt.savefig('Images/BTCXRPhis.png')

# %%
#scatterplot BTC XRP
plt.figure(figsize=(9,7))
plt.scatter(range(len(group1)), group1, s=100, label="BTC", alpha=0.75, c='gold', edgecolor='black')
plt.scatter(range(len(group10)), group10, s=100, label="XRP", alpha=0.4, c='royalblue', edgecolor='black')
plt.legend()
plt.title("Bitcoin and Ripple Distribution", fontsize=14)
plt.text(0, -.5, BTCXRP_ttest, fontsize=11)
plt.savefig('Images/BTCXRPscat.png')

# %%
DateList = Yahoo_Combined["Date"]
plt.scatter(DateList, group1, s=100, alpha=.5, label='BTC', marker='o', edgecolors='black', color="gold")
plt.scatter(DateList, group2, s=100, alpha=.5, label='BNB', marker='o', edgecolors='black', color="lightgreen")
plt.show()
